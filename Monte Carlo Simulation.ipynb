# %% [markdown]
# # Monte Carlo Simulation

# %% [markdown]
# This notebook will estimate European option prices numerically by implementing a Monte Carlo simulation of the geometric Brownian motion process.

# %% [markdown]
# ## About Monte Carlo Simulation

# %% [markdown]
# ## Code Implementation

# %% [markdown]
# ## European Option Price

# %% [markdown]
# ## Discussion
